# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv(r"train.csv")

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train.shape
# Out:
# (8523, 12)

# %%
sns.heatmap(train.isna());

# %%
train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train['Item_Weight'].fillna(train['Item_Weight'].mean(), inplace=True)

# %%
train.dropna(inplace=True)

# %%
sns.heatmap(train.isna());

# %%
train[['Item_Identifier','Item_Outlet_Sales']].groupby(['Item_Identifier']).agg('median')
# Out:
#                  Item_Outlet_Sales
# Item_Identifier
# DRA12                     992.7078
# DRA24                    3439.5228
# DRA59                    2868.9322
# DRB01                    1518.0240
# DRB13                    3605.3070
# ...                            ...
# NCZ30                    2530.7058
# NCZ41                    1752.3856
# NCZ42                    4740.4960
# NCZ53                    3580.0066
# NCZ54                    4711.2008
#
# [1555 rows x 1 columns]

# %%
train[['Item_Weight','Item_Outlet_Sales']].groupby(['Item_Weight']).agg('median')
# Out:
#              Item_Outlet_Sales
# Item_Weight
# 4.555                1565.9616
# 4.590                1358.2320
# 4.610                1831.6158
# 4.615                4893.6300
# 4.635                1927.4910
# ...                        ...
# 21.000               1356.2346
# 21.100               2015.3766
# 21.200               2954.1546
# 21.250               2470.1180
# 21.350               5206.5560
#
# [410 rows x 1 columns]

# %%
train[['Item_Fat_Content','Item_Outlet_Sales']].groupby(['Item_Fat_Content']).agg('median')
# Out:
#                   Item_Outlet_Sales
# Item_Fat_Content
# LF                        2028.6926
# Low Fat                   1907.5170
# Regular                   1974.4299
# low fat                   1722.4246
# reg                       1598.5858

# %%
train[['Item_Visibility','Item_Outlet_Sales']].groupby(['Item_Visibility']).agg('median')
# Out:
#                  Item_Outlet_Sales
# Item_Visibility
# 0.000000                 1844.2660
# 0.003575                 3229.7958
# 0.003589                 1691.7978
# 0.003598                 2922.1962
# 0.003607                 1384.1982
# ...                            ...
# 0.306543                  291.6204
# 0.308145                  889.5088
# 0.321115                  199.7400
# 0.325781                  761.0094
# 0.328391                  588.5672
#
# [5641 rows x 1 columns]

# %%
train[['Item_Type','Item_Outlet_Sales']].groupby(['Item_Type']).agg('median')
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Baking Goods                   1701.7848
# Breads                         2055.9904
# Breakfast                      1561.9668
# Canned                         1901.5248
# Dairy                          1851.5898
# Frozen Foods                   1808.3128
# Fruits and Vegetables          2022.7004
# Hard Drinks                    1940.1412
# Health and Hygiene             1884.2140
# Household                      2125.2336
# Meat                           1964.7758
# Others                         1837.6080
# Seafood                        2154.1959
# Snack Foods                    2084.9527
# Soft Drinks                    1617.2282
# Starchy Foods                  2181.1608

# %%
train[['Item_MRP','Item_Outlet_Sales']].groupby(['Item_MRP']).agg('median')
# Out:
#           Item_Outlet_Sales
# Item_MRP
# 31.2900            898.8300
# 31.4900            466.0600
# 31.8900            366.1900
# 31.9558            679.1160
# 32.0558           1018.6740
# ...                     ...
# 266.1884          4239.8144
# 266.2884          2914.8724
# 266.5884          3974.8260
# 266.6884          3974.8260
# 266.8884          5034.7796
#
# [4694 rows x 1 columns]

# %%
train[['Outlet_Identifier','Item_Outlet_Sales']].groupby(['Outlet_Identifier']).agg('median')
# Out:
#                    Item_Outlet_Sales
# Outlet_Identifier
# OUT013                     2050.6640
# OUT018                     1655.1788
# OUT019                      265.3213
# OUT027                     3364.9532
# OUT035                     2109.2544
# OUT046                     1945.8005
# OUT049                     1966.1074

# %%
train[['Outlet_Establishment_Year','Item_Outlet_Sales']].groupby(['Outlet_Establishment_Year']).agg('median')
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1985                               1845.5976
# 1987                               2050.6640
# 1997                               1945.8005
# 1999                               1966.1074
# 2004                               2109.2544
# 2009                               1655.1788

# %%
train[['Outlet_Size','Item_Outlet_Sales']].groupby(['Outlet_Size']).agg('median')
# Out:
#              Item_Outlet_Sales
# Outlet_Size
# High                 2050.6640
# Medium               2251.0698
# Small                1544.6560

# %%
train[['Outlet_Location_Type','Item_Outlet_Sales']].groupby(['Outlet_Location_Type']).agg('median')
# Out:
#                       Item_Outlet_Sales
# Outlet_Location_Type
# Tier 1                        1487.3972
# Tier 2                        2109.2544
# Tier 3                        2251.0698

# %%
train[['Outlet_Type','Item_Outlet_Sales']].groupby(['Outlet_Type']).agg('median')
# Out:
#                    Item_Outlet_Sales
# Outlet_Type
# Grocery Store               265.3213
# Supermarket Type1          2024.0320
# Supermarket Type2          1655.1788
# Supermarket Type3          3364.9532

# %%
train.drop(['Item_Visibility', 'Item_Identifier', 'Outlet_Establishment_Year'], axis=1, inplace=True)

# %%
train.isna().sum()
# Out:
# Item_Weight             0
# Item_Fat_Content        0
# Item_Type               0
# Item_MRP                0
# Outlet_Identifier       0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
train['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3641
# Regular    2076
# LF          233
# reg          82
# low fat      81
# Name: Item_Fat_Content, dtype: int64

# %%
# train['Item_Identifier'] = le.fit_transform(train['Item_Identifier'])
train['Item_Fat_Content'] = train['Item_Fat_Content'].replace({'LF':0, 'Low Fat':1, 'Regular':2, 'low fat':3, 'reg':4})

# %%
train['Item_Fat_Content'].value_counts()
# Out:
# 1    3641
# 2    2076
# 0     233
# 4      82
# 3      81
# Name: Item_Fat_Content, dtype: int64

# %%
train['Outlet_Identifier'] = train['Outlet_Identifier'].replace({'OUT013':0, 'OUT018':1, 'OUT019':2, 'OUT027':3, 'OUT035':4, 'OUT046':5, 'OUT049':6,'OUT010':7})

# %%
train['Item_Type'] = train['Item_Type'].replace({
'Fruits and Vegetables':0, 'Snack Foods':1, 'Household':2,'Frozen Foods':3, 'Dairy':4, 'Canned':5, 'Baking Goods':6, 'Health and Hygiene':7, 'Soft Drinks':8, 'Meat':9, 'Breads':10, 'Hard Drinks':11, 'Others':12, 'Starchy Foods':13, 'Breakfast':14, 'Seafood':15
})

# %%
train['Outlet_Size'] = train['Outlet_Size'].replace({"Small": 0, "Medium": 1, "High": 2})
train['Outlet_Location_Type'] = train['Outlet_Location_Type'].replace({"Tier 1": 0, "Tier 2": 1, 'Tier 3': 2})
train['Outlet_Type'] = train['Outlet_Type'].replace({"Grocery Store": 0, "Supermarket Type1":1, "Supermarket Type2":2, "Supermarket Type3": 3})

# %%
train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  Outlet_Identifier  \
# 0           9.300                 1          4  249.8092                  6
# 1           5.920                 2          8   48.2692                  1
# 2          17.500                 1          9  141.6180                  6
# 4           8.930                 1          2   53.8614                  0
# 5          10.395                 2          6   51.4008                  1
# ...           ...               ...        ...       ...                ...
# 8517       20.750                 4          3  178.8318                  5
# 8518        6.865                 1          1  214.5218                  0
# 8520       10.600                 1          7   85.1224                  4
# 8521        7.210                 2          1  103.1332                  1
# 8522       14.800                 1          8   75.4670                  5
#
# ...

# %%
plt.figure(figsize=(10, 5)) 
sns.heatmap(data=train.corr(), annot=True);

# %%
train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  Outlet_Identifier  \
# 0           9.300                 1          4  249.8092                  6
# 1           5.920                 2          8   48.2692                  1
# 2          17.500                 1          9  141.6180                  6
# 4           8.930                 1          2   53.8614                  0
# 5          10.395                 2          6   51.4008                  1
# ...           ...               ...        ...       ...                ...
# 8517       20.750                 4          3  178.8318                  5
# 8518        6.865                 1          1  214.5218                  0
# 8520       10.600                 1          7   85.1224                  4
# 8521        7.210                 2          1  103.1332                  1
# 8522       14.800                 1          8   75.4670                  5
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(train.corr(), annot=True);

# %%
plt.figure(figsize=(25, 5)) 
sns.boxplot(data=train);

# %%
#item_Item_Outlet_Sales distribution
plt.figure(figsize=(6,6))
sns.distplot(train['Item_Outlet_Sales'])
plt.show()
# Out:
# C:\Users\Win-10\AppData\Local\Temp\ipykernel_14740\4187940103.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Item_Outlet_Sales'])

# %%
#Item_Type column
plt.figure(figsize=(30,6))
sns.countplot(x='Item_Type',data=train)

plt.show()

# %%
train['Item_MRP'].hist(bins=100)
# Out:
# <Axes: >

# %%
X = train.drop('Item_Outlet_Sales', axis=1)
Y = train['Item_Outlet_Sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (6113, 8) (4890, 8) (1223, 8)

# %%
test_X = X.iloc[0:500] 
test_Y = Y.iloc[0:500]

# %%
from sklearn.metrics import r2_score

# %%
import xgboost as xg

# %%
xgb = xg.XGBRegressor(n_estimators=500)

# %%
xgb.fit(X,Y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb_preds = xgb.predict(test_X)

# %%
r2_score(test_Y, xgb_preds)
# Out:
# 0.9736190811895816

# %%
import pickle

# %%
pickle.dump(xgb, open(r"model.pkl", 'wb'))

# %%
model = pickle.load(open('model.pkl', 'rb'))

# %%
model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
